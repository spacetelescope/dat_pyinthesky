# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(74)

# %%
R = 4
N = int(1e4)

# %%
xs = R * (np.random.rand(N) * 2 - 1)
ys = R * (np.random.rand(N) * 2 - 1)
valid = xs**2 + ys**2 <= R**2

# %%
plt.scatter(xs[valid], ys[valid], s=1, c='#e56020')

# %%
4 * valid.sum() / N
# Out:
# 3.1588
